# %%
import pandas as pd
# Load your dataset exactly like the model did
df = pd.read_csv('processed.cleveland.data', header=None, na_values='?')

# Check the unique values for the categorical columns
print("--- VERIFICATION ---")
print(f"CP (Chest Pain) values: {sorted(df[2].dropna().unique())}")
print(f"Slope values:           {sorted(df[10].dropna().unique())}")
print(f"Thal values:            {sorted(df[12].dropna().unique())}")
print("--------------------")
# Out:
# --- VERIFICATION ---
# CP (Chest Pain) values: [1.0, 2.0, 3.0, 4.0]
# Slope values:           [1.0, 2.0, 3.0]
# Thal values:            [3.0, 6.0, 7.0]
# --------------------
